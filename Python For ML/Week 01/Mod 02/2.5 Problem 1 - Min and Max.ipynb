# %%
data = input()

numbers = data.split()

x = int(numbers[0])
y = int(numbers[1])
z = int(numbers[2])

min = x
max = x

if min > y:
    min = y
if min > z:
    min = z
    
if max < y:
    max = y
if max < z:
    max = z
    
print(min, max)
# Out:
# 1 3
