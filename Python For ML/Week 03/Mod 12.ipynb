# %%
import pandas as pd

df = pd.read_csv("./sample_data/student_data.csv")

print(df)

print(type(df))
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
student_id = df['StudentID']

print(student_id)
print(type(student_id))
# Out:
# 0     PH1001
# 1     PH1002
# 2     PH1003
# 3     PH1004
# 4     PH1005
# 5     PH1006
# 6     PH1007
# 7     PH1008
# 8     PH1009
# 9     PH1010
# 10    PH1011
# 11    PH1012
# 12    PH1013
# 13    PH1014
# 14    PH1015
# 15    PH1016
# 16    PH1017
# 17    PH1018
# 18    PH1019
# 19    PH1020
# Name: StudentID, dtype: object
# <class 'pandas.core.series.Series'>

# %%
csv_data = pd.read_csv("./sample_data/student_data.csv", index_col="StudentID")

print(csv_data)
# Out:
#                    FullName  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1001          Alif Rahman                  85.0             85.0
# PH1002        Fatima Akhter                  92.0             92.0
# PH1003        Imran Hossain                  88.0             88.0
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
# PH1006          Laila Begum                  75.0             75.0
# PH1007       Mahmudul Hasan                  80.0             80.0
# PH1008          Nadia Islam                  81.0             81.0
# PH1009           Omar Faruq                  72.0             72.0
# PH1010         Priya Sharma                  89.0             89.0
# PH1011         Rahim Sheikh                   NaN              NaN
# PH1012      Sadia Chowdhury                  85.0             85.0
# PH1013         Tanvir Ahmed                  75.0             75.0
# ...

# %%
csv_data
# Out:
#                    FullName  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1001          Alif Rahman                  85.0             85.0
# PH1002        Fatima Akhter                  92.0             92.0
# PH1003        Imran Hossain                  88.0             88.0
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
# PH1006          Laila Begum                  75.0             75.0
# PH1007       Mahmudul Hasan                  80.0             80.0
# PH1008          Nadia Islam                  81.0             81.0
# PH1009           Omar Faruq                  72.0             72.0
# PH1010         Priya Sharma                  89.0             89.0
# PH1011         Rahim Sheikh                   NaN              NaN
# PH1012      Sadia Chowdhury                  85.0             85.0
# PH1013         Tanvir Ahmed                  75.0             75.0
# ...

# %%
csv_data.head()
# Out:
#                    FullName  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1001          Alif Rahman                  85.0             85.0
# PH1002        Fatima Akhter                  92.0             92.0
# PH1003        Imran Hossain                  88.0             88.0
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
#
#            Python Marks CompletionStatus EnrollmentDate Instructor    Location
# StudentID
# PH1001             88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# PH1002              NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# PH1003             85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# PH1004             82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# PH1005             95.0      In Progress     2024-03-05  Mr. Karim  Chattogram

# %%
csv_data.head(3)
# Out:
#                 FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# StudentID
# PH1001       Alif Rahman                  85.0             85.0          88.0
# PH1002     Fatima Akhter                  92.0             92.0           NaN
# PH1003     Imran Hossain                  88.0             88.0          85.0
#
#           CompletionStatus EnrollmentDate Instructor    Location
# StudentID
# PH1001           Completed     2024-01-15  Mr. Karim       Dhaka
# PH1002         In Progress     2024-01-20  Ms. Salma  Chattogram
# PH1003           Completed     2024-02-10  Mr. Karim       Dhaka

# %%
csv_data.tail()
# Out:
#                FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# StudentID
# PH1016     Ziaur Rahman                  94.0             94.0           NaN
# PH1017      Afsana Mimi                  90.0             90.0          93.0
# PH1018      Babul Ahmed                  88.0             88.0          85.0
# PH1019     Faria Rahman                   NaN              NaN           NaN
# PH1020       Nasir Khan                  86.0             86.0          89.0
#
#           CompletionStatus EnrollmentDate Instructor    Location
# StudentID
# PH1016         In Progress     2024-08-21  Ms. Salma  Chattogram
# PH1017           Completed     2025-09-01  Mr. Karim       Dhaka
# PH1018           Completed     2025-09-05  Ms. Salma      Sylhet
# PH1019         Not Started     2025-09-15  Mr. David  Chattogram
# PH1020           Completed     2025-10-02  Ms. Salma       Dhaka

# %%
csv_data.tail(3)
# Out:
#                FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# StudentID
# PH1018      Babul Ahmed                  88.0             88.0          85.0
# PH1019     Faria Rahman                   NaN              NaN           NaN
# PH1020       Nasir Khan                  86.0             86.0          89.0
#
#           CompletionStatus EnrollmentDate Instructor    Location
# StudentID
# PH1018           Completed     2025-09-05  Ms. Salma      Sylhet
# PH1019         Not Started     2025-09-15  Mr. David  Chattogram
# PH1020           Completed     2025-10-02  Ms. Salma       Dhaka

# %%
csv_data.columns
# Out:
# Index(['FullName', 'Data Structure Marks', 'Algorithm Marks', 'Python Marks',
#        'CompletionStatus', 'EnrollmentDate', 'Instructor', 'Location'],
#       dtype='object')

# %%
cols = list(csv_data.columns)
print(cols)
print(type(cols))
# Out:
# ['FullName', 'Data Structure Marks', 'Algorithm Marks', 'Python Marks', 'CompletionStatus', 'EnrollmentDate', 'Instructor', 'Location']
# <class 'list'>

# %%
import numpy as np

df.columns

cols = np.array(df.columns)
print(cols)
print(type(cols))
# Out:
# ['StudentID' 'FullName' 'Data Structure Marks' 'Algorithm Marks'
#  'Python Marks' 'CompletionStatus' 'EnrollmentDate' 'Instructor'
#  'Location']
# <class 'numpy.ndarray'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudentID             20 non-null     object
#  1   FullName              20 non-null     object
#  2   Data Structure Marks  16 non-null     float64
#  3   Algorithm Marks       16 non-null     float64
#  4   Python Marks          15 non-null     float64
#  5   CompletionStatus      20 non-null     object
#  6   EnrollmentDate        20 non-null     object
#  7   Instructor            20 non-null     object
#  8   Location              20 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 1.5+ KB

# %%
df.sample(10)
# Out:
#    StudentID         FullName  Data Structure Marks  Algorithm Marks  \
# 11    PH1012  Sadia Chowdhury                  85.0             85.0
# 5     PH1006      Laila Begum                  75.0             75.0
# 18    PH1019     Faria Rahman                   NaN              NaN
# 0     PH1001      Alif Rahman                  85.0             85.0
# 12    PH1013     Tanvir Ahmed                  75.0             75.0
# 15    PH1016     Ziaur Rahman                  94.0             94.0
# 7     PH1008      Nadia Islam                  81.0             81.0
# 9     PH1010     Priya Sharma                  89.0             89.0
# 6     PH1007   Mahmudul Hasan                  80.0             80.0
# 1     PH1002    Fatima Akhter                  92.0             92.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 11          87.0        Completed     2024-06-14  Ms. Salma  Chattogram
# ...

# %%
df.describe()
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks
# count             16.000000        16.000000     15.000000
# mean              84.000000        84.000000     85.666667
# std                6.501282         6.501282      5.394000
# min               72.000000        72.000000     76.000000
# 25%               79.500000        79.500000     83.000000
# 50%               85.500000        85.500000     85.000000
# 75%               88.250000        88.250000     88.500000
# max               94.000000        94.000000     95.000000

# %%
my_list = [['Alice', 25], ['Bob', 30], ['Charlie', 35]]

list_df = pd.DataFrame(my_list, columns=['Name', 'Age'], index=[1, 2, 3])

print(list_df)
print(type(list_df))
# Out:
#       Name  Age
# 1    Alice   25
# 2      Bob   30
# 3  Charlie   35
# <class 'pandas.core.frame.DataFrame'>

# %%
my_tuple = [('Alice', 25), ('Bob', 30), ('Charlie', 35)]

tuple_df = pd.DataFrame(my_tuple, columns=['Name', 'Age'], index=[1, 2, 3])

print(tuple_df)
# Out:
#       Name  Age
# 1    Alice   25
# 2      Bob   30
# 3  Charlie   35

# %%
my_dict = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}

dict_df = pd.DataFrame(my_dict, index=[1, 2, 3])

print(dict_df)
# Out:
#       Name  Age
# 1    Alice   25
# 2      Bob   30
# 3  Charlie   35

# %%
my_data = [
    {'Name': 'Alice', 'Age': 25},
    {'Name': 'Bob', 'Age': 30},
    {'Name': 'Charlie'}
]

data_df = pd.DataFrame(my_data, index=[1, 2, 3])

print(data_df)
# Out:
#       Name   Age
# 1    Alice  25.0
# 2      Bob  30.0
# 3  Charlie   NaN

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['FullName']

print(type(df['FullName']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# loc[row (index), column (features)]

df.loc[0]
print(type(df.loc[0]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.loc[[2, 3, 19]]
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 19    PH1020        Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor Location
# 2           85.0        Completed     2024-02-10  Mr. Karim    Dhaka
# 3           82.0        Completed     2024-02-12  Ms. Salma   Sylhet
# 19          89.0        Completed     2025-10-02  Ms. Salma    Dhaka

# %%
df.loc[3:19]
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 13    PH1014        Urmi Akter                   NaN              NaN
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# ...

# %%
df.loc[:, 'StudentID']
# Out:
# 0     PH1001
# 1     PH1002
# 2     PH1003
# 3     PH1004
# 4     PH1005
# 5     PH1006
# 6     PH1007
# 7     PH1008
# 8     PH1009
# 9     PH1010
# 10    PH1011
# 11    PH1012
# 12    PH1013
# 13    PH1014
# 14    PH1015
# 15    PH1016
# 16    PH1017
# 17    PH1018
# 18    PH1019
# 19    PH1020
# Name: StudentID, dtype: object

# %%
df.loc[5: 10, ['StudentID', 'FullName']]

print(type(df.loc[5: 10, ['StudentID', 'FullName']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# df_index = df.set_index('StudentID', inplace=True)

df_index = df.set_index('StudentID')
df_index
# Out:
#                    FullName  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1001          Alif Rahman                  85.0             85.0
# PH1002        Fatima Akhter                  92.0             92.0
# PH1003        Imran Hossain                  88.0             88.0
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
# PH1006          Laila Begum                  75.0             75.0
# PH1007       Mahmudul Hasan                  80.0             80.0
# PH1008          Nadia Islam                  81.0             81.0
# PH1009           Omar Faruq                  72.0             72.0
# PH1010         Priya Sharma                  89.0             89.0
# PH1011         Rahim Sheikh                   NaN              NaN
# PH1012      Sadia Chowdhury                  85.0             85.0
# PH1013         Tanvir Ahmed                  75.0             75.0
# ...

# %%
df_index.iloc[0: 5]
# Out:
#                    FullName  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1001          Alif Rahman                  85.0             85.0
# PH1002        Fatima Akhter                  92.0             92.0
# PH1003        Imran Hossain                  88.0             88.0
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
#
#            Python Marks CompletionStatus EnrollmentDate Instructor    Location
# StudentID
# PH1001             88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# PH1002              NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# PH1003             85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# PH1004             82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# PH1005             95.0      In Progress     2024-03-05  Mr. Karim  Chattogram

# %%
df_index.iloc[0: 5, 1:3]
# Out:
#            Data Structure Marks  Algorithm Marks
# StudentID
# PH1001                     85.0             85.0
# PH1002                     92.0             92.0
# PH1003                     88.0             88.0
# PH1004                     78.0             78.0
# PH1005                      NaN              NaN

# %%
df_index.rename(columns={'FullName': 'Name'}, inplace=True)
df_index
# Out:
#                        Name  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1001          Alif Rahman                  85.0             85.0
# PH1002        Fatima Akhter                  92.0             92.0
# PH1003        Imran Hossain                  88.0             88.0
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
# PH1006          Laila Begum                  75.0             75.0
# PH1007       Mahmudul Hasan                  80.0             80.0
# PH1008          Nadia Islam                  81.0             81.0
# PH1009           Omar Faruq                  72.0             72.0
# PH1010         Priya Sharma                  89.0             89.0
# PH1011         Rahim Sheikh                   NaN              NaN
# PH1012      Sadia Chowdhury                  85.0             85.0
# PH1013         Tanvir Ahmed                  75.0             75.0
# ...

# %%
df.drop(0,  inplace=True)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
df.drop('StudentID', axis=1, inplace=True)
df
# Out:
#             FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 1      Fatima Akhter                  92.0             92.0           NaN
# 2      Imran Hossain                  88.0             88.0          85.0
# 3   Jannatul Ferdous                  78.0             78.0          82.0
# 4        Kamal Uddin                   NaN              NaN          95.0
# 5        Laila Begum                  75.0             75.0          78.0
# 6     Mahmudul Hasan                  80.0             80.0           NaN
# 7        Nadia Islam                  81.0             81.0          85.0
# 8         Omar Faruq                  72.0             72.0          76.0
# 9       Priya Sharma                  89.0             89.0          88.0
# 10      Rahim Sheikh                   NaN              NaN          91.0
# 11   Sadia Chowdhury                  85.0             85.0          87.0
# 12      Tanvir Ahmed                  75.0             75.0          79.0
# ...

# %%
df.loc[1, 'FullName'] = 'John Doe'
df
# Out:
#             FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 1           John Doe                  92.0             92.0           NaN
# 2      Imran Hossain                  88.0             88.0          85.0
# 3   Jannatul Ferdous                  78.0             78.0          82.0
# 4        Kamal Uddin                   NaN              NaN          95.0
# 5        Laila Begum                  75.0             75.0          78.0
# 6     Mahmudul Hasan                  80.0             80.0           NaN
# 7        Nadia Islam                  81.0             81.0          85.0
# 8         Omar Faruq                  72.0             72.0          76.0
# 9       Priya Sharma                  89.0             89.0          88.0
# 10      Rahim Sheikh                   NaN              NaN          91.0
# 11   Sadia Chowdhury                  85.0             85.0          87.0
# 12      Tanvir Ahmed                  75.0             75.0          79.0
# ...

# %%
df.loc[1: 3, 'Algorithm Marks'] += 2
df.head()
# Out:
#            FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 1          John Doe                  92.0             96.0           NaN
# 2     Imran Hossain                  88.0             92.0          85.0
# 3  Jannatul Ferdous                  78.0             82.0          82.0
# 4       Kamal Uddin                   NaN              NaN          95.0
# 5       Laila Begum                  75.0             75.0          78.0
#
#   CompletionStatus EnrollmentDate Instructor    Location
# 1      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2        Completed     2024-02-10  Mr. Karim       Dhaka
# 3        Completed     2024-02-12  Ms. Salma      Sylhet
# 4      In Progress     2024-03-05  Mr. Karim  Chattogram
# 5        Completed     2024-03-08  Ms. Salma    Rajshahi

# %%
for i, series in df.iterrows():
  print(f"Index: {i}")
  print(f"FullName: {series['FullName']}")
  print(f"Algorithm Marks: {series['Algorithm Marks']}")
  print(f"Python Marks: {series['Python Marks']}")
  print()
# Out:
# Index: 1
# FullName: John Doe
# Algorithm Marks: 96.0
# Python Marks: nan
#
# Index: 2
# FullName: Imran Hossain
# Algorithm Marks: 92.0
# Python Marks: 85.0
#
# Index: 3
# FullName: Jannatul Ferdous
# Algorithm Marks: 82.0
# Python Marks: 82.0
#
# Index: 4
# FullName: Kamal Uddin
# Algorithm Marks: nan
# Python Marks: 95.0
#
# Index: 5
# FullName: Laila Begum
# Algorithm Marks: 75.0
# Python Marks: 78.0
#
# Index: 6
# FullName: Mahmudul Hasan
# Algorithm Marks: 80.0
# Python Marks: nan
#
# Index: 7
# FullName: Nadia Islam
# Algorithm Marks: 81.0
# Python Marks: 85.0
#
# Index: 8
# FullName: Omar Faruq
# Algorithm Marks: 72.0
# Python Marks: 76.0
#
# Index: 9
# FullName: Priya Sharma
# Algorithm Marks: 89.0
# Python Marks: 88.0
#
# Index: 10
# FullName: Rahim Sheikh
# Algorithm Marks: nan
# Python Marks: 91.0
#
# Index: 11
# FullName: Sadia Chowdhury
# Algorithm Marks: 85.0
# Python Marks: 87.0
#
# Index: 12
# FullName: Tanvir Ahmed
# Algorithm Marks: 75.0
# Python Marks: 79.0
#
# ...

# %%
for i in df.itertuples():
  print(i)
# Out:
# Pandas(Index=1, FullName='John Doe', _2=92.0, _3=96.0, _4=nan, CompletionStatus='In Progress', EnrollmentDate='2024-01-20', Instructor='Ms. Salma', Location='Chattogram')
# Pandas(Index=2, FullName='Imran Hossain', _2=88.0, _3=92.0, _4=85.0, CompletionStatus='Completed', EnrollmentDate='2024-02-10', Instructor='Mr. Karim', Location='Dhaka')
# Pandas(Index=3, FullName='Jannatul Ferdous', _2=78.0, _3=82.0, _4=82.0, CompletionStatus='Completed', EnrollmentDate='2024-02-12', Instructor='Ms. Salma', Location='Sylhet')
# Pandas(Index=4, FullName='Kamal Uddin', _2=nan, _3=nan, _4=95.0, CompletionStatus='In Progress', EnrollmentDate='2024-03-05', Instructor='Mr. Karim', Location='Chattogram')
# Pandas(Index=5, FullName='Laila Begum', _2=75.0, _3=75.0, _4=78.0, CompletionStatus='Completed', EnrollmentDate='2024-03-08', Instructor='Ms. Salma', Location='Rajshahi')
# ...

# %%
for i in df.itertuples(index=False):
  print(i)
# Out:
# Pandas(FullName='John Doe', _1=92.0, _2=96.0, _3=nan, CompletionStatus='In Progress', EnrollmentDate='2024-01-20', Instructor='Ms. Salma', Location='Chattogram')
# Pandas(FullName='Imran Hossain', _1=88.0, _2=92.0, _3=85.0, CompletionStatus='Completed', EnrollmentDate='2024-02-10', Instructor='Mr. Karim', Location='Dhaka')
# Pandas(FullName='Jannatul Ferdous', _1=78.0, _2=82.0, _3=82.0, CompletionStatus='Completed', EnrollmentDate='2024-02-12', Instructor='Ms. Salma', Location='Sylhet')
# Pandas(FullName='Kamal Uddin', _1=nan, _2=nan, _3=95.0, CompletionStatus='In Progress', EnrollmentDate='2024-03-05', Instructor='Mr. Karim', Location='Chattogram')
# Pandas(FullName='Laila Begum', _1=75.0, _2=75.0, _3=78.0, CompletionStatus='Completed', EnrollmentDate='2024-03-08', Instructor='Ms. Salma', Location='Rajshahi')
# Pandas(FullName='Mahmudul Hasan', _1=80.0, _2=80.0, _3=nan, CompletionStatus='In Progress', EnrollmentDate='2024-04-01', Instructor='Mr. Karim', Location='Dhaka')
# ...

# %%
df = df.sort_values('Data Structure Marks', ascending=True)
df
# Out:
#             FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 8         Omar Faruq                  72.0             72.0          76.0
# 5        Laila Begum                  75.0             75.0          78.0
# 12      Tanvir Ahmed                  75.0             75.0          79.0
# 3   Jannatul Ferdous                  78.0             82.0          82.0
# 6     Mahmudul Hasan                  80.0             80.0           NaN
# 7        Nadia Islam                  81.0             81.0          85.0
# 11   Sadia Chowdhury                  85.0             85.0          87.0
# 14      Wahiduzzaman                  86.0             86.0          84.0
# 19        Nasir Khan                  86.0             86.0          89.0
# 17       Babul Ahmed                  88.0             88.0          85.0
# 2      Imran Hossain                  88.0             92.0          85.0
# 9       Priya Sharma                  89.0             89.0          88.0
# ...

# %%
df = df.sort_values(['Data Structure Marks', 'Algorithm Marks'], ascending=False)
df
# Out:
#             FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 15      Ziaur Rahman                  94.0             94.0           NaN
# 1           John Doe                  92.0             96.0           NaN
# 16       Afsana Mimi                  90.0             90.0          93.0
# 9       Priya Sharma                  89.0             89.0          88.0
# 2      Imran Hossain                  88.0             92.0          85.0
# 17       Babul Ahmed                  88.0             88.0          85.0
# 14      Wahiduzzaman                  86.0             86.0          84.0
# 19        Nasir Khan                  86.0             86.0          89.0
# 11   Sadia Chowdhury                  85.0             85.0          87.0
# 7        Nadia Islam                  81.0             81.0          85.0
# 6     Mahmudul Hasan                  80.0             80.0           NaN
# 3   Jannatul Ferdous                  78.0             82.0          82.0
# ...

# %%
df = df.sort_values(['Data Structure Marks', 'Algorithm Marks'], ascending=[False, True])
df
# Out:
#             FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 15      Ziaur Rahman                  94.0             94.0           NaN
# 1           John Doe                  92.0             96.0           NaN
# 16       Afsana Mimi                  90.0             90.0          93.0
# 9       Priya Sharma                  89.0             89.0          88.0
# 17       Babul Ahmed                  88.0             88.0          85.0
# 2      Imran Hossain                  88.0             92.0          85.0
# 14      Wahiduzzaman                  86.0             86.0          84.0
# 19        Nasir Khan                  86.0             86.0          89.0
# 11   Sadia Chowdhury                  85.0             85.0          87.0
# 7        Nadia Islam                  81.0             81.0          85.0
# 6     Mahmudul Hasan                  80.0             80.0           NaN
# 3   Jannatul Ferdous                  78.0             82.0          82.0
# ...

# %%
not_started = df[df['CompletionStatus'] == 'Not Started']
not_started
# Out:
#         FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 13    Urmi Akter                   NaN              NaN           NaN
# 18  Faria Rahman                   NaN              NaN           NaN
#
#    CompletionStatus EnrollmentDate Instructor    Location
# 13      Not Started     2024-07-09  Ms. Salma    Rajshahi
# 18      Not Started     2025-09-15  Mr. David  Chattogram

# %%
completed = df[df['CompletionStatus'] == 'Completed']
completed
# Out:
#             FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 16       Afsana Mimi                  90.0             90.0          93.0
# 9       Priya Sharma                  89.0             89.0          88.0
# 17       Babul Ahmed                  88.0             88.0          85.0
# 2      Imran Hossain                  88.0             92.0          85.0
# 14      Wahiduzzaman                  86.0             86.0          84.0
# 19        Nasir Khan                  86.0             86.0          89.0
# 11   Sadia Chowdhury                  85.0             85.0          87.0
# 7        Nadia Islam                  81.0             81.0          85.0
# 3   Jannatul Ferdous                  78.0             82.0          82.0
# 5        Laila Begum                  75.0             75.0          78.0
# 12      Tanvir Ahmed                  75.0             75.0          79.0
# 8         Omar Faruq                  72.0             72.0          76.0
#
# ...

# %%
best_student = completed.loc[(completed['Python Marks'] >= 90) & (completed['Data Structure Marks'] >= 90)]
best_student
# Out:
#        FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 16  Afsana Mimi                  90.0             90.0          93.0
#
#    CompletionStatus EnrollmentDate Instructor Location
# 16        Completed     2025-09-01  Mr. Karim    Dhaka

# %% [markdown]
# [1757. Recyclable and Low Fat Products](https://leetcode.com/problems/recyclable-and-low-fat-products/description/)

# %%
import pandas as pd

def find_products(products: pd.DataFrame) -> pd.DataFrame:
    ans = products.loc[(products['low_fats'] == 'Y') & (products['recyclable'] == 'Y'), ['product_id']]
    return ans
