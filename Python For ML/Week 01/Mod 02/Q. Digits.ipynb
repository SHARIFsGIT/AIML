# %%
tc = int(input())

for i in range(tc):
    n = int(input())
    
    if n == 0:
        print(0)
        continue
    
    while n > 0:
        print(n%10, end=" ")
        n //= 10    # n = int(n/10)
    print()
# Out:
# 0

# %%
x = 5

if x > 3:
    print("A")
elif x > 1:
    print("B")
else:
    print("C")
# Out:
# A

# %%
i = 0

while i < 3:
    i+= 1
    if i == 2:
        break
print("Done")
# Out:
# Done

# %%
for i in range(2):
    for j in range(3):
        if j == 1:
            break
        print(i, j)
# Out:
# 0 0
# 1 0

# %%
for i in range(2):
    for j in range(3):
        if j == 1:
            continue
        print(i, j)
# Out:
# 0 0
# 0 2
# 1 0
# 1 2

# %%
s = 0

for i in range(1, 5):
    if i % 2 == 0:
        s += i
    else:
        s -= i
print(s)
# Out:
# 2
